# %% [markdown]
# **Building a Markov Chain Advertising Attribution Model**

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas_profiling
import collections
from collections import defaultdict

# %%
df = pd.read_csv('/Users/mahimakaushiva/Desktop/Personal_Projects/Marketing attribution/attribution data.csv')
df.head()
# Out:
#                       cookie                  time interaction  conversion  \
# 0  00000FkCnDfDDf0iC97iC703B  2018-07-03T13:02:11Z  impression           0
# 1  00000FkCnDfDDf0iC97iC703B  2018-07-17T19:15:07Z  impression           0
# 2  00000FkCnDfDDf0iC97iC703B  2018-07-24T15:51:46Z  impression           0
# 3  00000FkCnDfDDf0iC97iC703B  2018-07-29T07:44:51Z  impression           0
# 4  0000nACkD9nFkBBDECD3ki00E  2018-07-03T09:44:57Z  impression           0
#
#    conversion_value         channel
# 0               0.0       Instagram
# 1               0.0  Online Display
# 2               0.0  Online Display
# 3               0.0  Online Display
# 4               0.0     Paid Search

# %%
pandas_profiling.ProfileReport(df)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
df['time']= pd.to_datetime(df['time'])
df.head()
# Out:
#                       cookie                      time interaction  \
# 0  00000FkCnDfDDf0iC97iC703B 2018-07-03 13:02:11+00:00  impression
# 1  00000FkCnDfDDf0iC97iC703B 2018-07-17 19:15:07+00:00  impression
# 2  00000FkCnDfDDf0iC97iC703B 2018-07-24 15:51:46+00:00  impression
# 3  00000FkCnDfDDf0iC97iC703B 2018-07-29 07:44:51+00:00  impression
# 4  0000nACkD9nFkBBDECD3ki00E 2018-07-03 09:44:57+00:00  impression
#
#    conversion  conversion_value         channel
# 0           0               0.0       Instagram
# 1           0               0.0  Online Display
# 2           0               0.0  Online Display
# 3           0               0.0  Online Display
# 4           0               0.0     Paid Search

# %%
plt.title('value count of interactions per channel')
plt.ylabel('number of interactions')
plt.xlabel('channel')
df['channel'].value_counts().plot.bar()

# %%
# creating a new column to indicate the order of touch-points for each user

df = df.sort_values(['cookie', 'time'], ascending= [False, True])
df['order_of_visit'] = df.groupby('cookie').cumcount()+1
df.head()
# Out:
#                            cookie                      time interaction  \
# 586736  ooooohAFofEnonEikhAi3fF9o 2018-07-14 17:17:12+00:00  impression
# 586734  ooooiBh70D3k3BfAhDFfii9h7 2018-07-03 12:57:25+00:00  impression
# 586735  ooooiBh70D3k3BfAhDFfii9h7 2018-07-19 08:17:59+00:00  impression
# 586731  ooooEiB0CCoEf9fiiC90Dfhfk 2018-07-06 23:30:38+00:00  impression
# 586732  ooooEiB0CCoEf9fiiC90Dfhfk 2018-07-12 23:50:45+00:00  impression
#
#         conversion  conversion_value         channel  order_of_visit
# 586736           0               0.0     Paid Search               1
# 586734           0               0.0     Paid Search               1
# 586735           0               0.0    Online Video               2
# 586731           0               0.0  Online Display               1
# 586732           0               0.0  Online Display               2

# %%
df['channel'].tolist()
# Out:
# ['Paid Search',
#  'Paid Search',
#  'Online Video',
#  'Online Display',
#  'Online Display',
#  'Online Display',
#  'Online Display',
#  'Online Display',
#  'Paid Search',
#  'Online Display',
#  'Instagram',
#  'Facebook',
#  'Instagram',
#  'Facebook',
#  'Instagram',
#  'Facebook',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Instagram',
#  'Facebook',
#  'Online Video',
#  'Paid Search',
#  'Online Video',
#  'Online Video',
#  'Online Video',
#  'Facebook',
#  'Facebook',
#  'Online Display',
#  'Online Display',
#  'Paid Search',
#  'Facebook',
#  'Paid Search',
#  'Paid Search',
#  'Online Display',
#  'Online Display',
#  'Online Display',
#  'Online Video',
#  'Paid Search',
#  'Facebook',
#  'Instagram',
#  'Online Display',
#  'Paid Search',
#  'Paid Search',
#  'Facebook',
#  'Facebook',
#  'Facebook',
#  'Instagram',
# ...

# %%
# converting the dataframe to represent the path for each user in chronological order
# grouping the chronological touch points into a list and merging the final conversion / non-conversion to show 'conversion' or 'null' at the end of the user journey

df_paths = df.groupby('cookie')['channel'].aggregate(lambda x: x.unique().tolist()).reset_index()

df_last_interaction = df.drop_duplicates('cookie', keep ='last')[['cookie', 'conversion']]
df_paths = pd.merge(df_paths, df_last_interaction, how= 'left', on='cookie')

df_paths['path'] = np.where(df_paths['conversion'] == 0, 
                           ['Start,'] + df_paths['channel'].apply(','.join) + [',Null'],
                           ['Start,'] + df_paths['channel'].apply(','.join) + [',Conversion'])

df_paths['path'] = df_paths['path'].str.split(',')
df_paths = df_paths[['cookie', 'path']]
df_paths.head()
# Out:
#                       cookie                                      path
# 0  00000FkCnDfDDf0iC97iC703B  [Start, Instagram, Online Display, Null]
# 1  0000nACkD9nFkBBDECD3ki00E                [Start, Paid Search, Null]
# 2  0003EfE37E93D0BC03iBhBBhF                [Start, Paid Search, Null]
# 3  00073CFE3FoFCn70fBhB3kfon                  [Start, Instagram, Null]
# 4  00079hhBkDF3k3kDkiFi9EFAD                [Start, Paid Search, Null]

# %% [markdown]
# *Building the Markov Chain*

# %%
# this consists of two steps -
# 1. building the transition probabilities of moving from one touch point to another in our state-space
# 2. calculating the removal effects

list_of_paths = df_paths['path']
total_conversions = sum(path.count('Conversion') for path in df_paths['path'].tolist())
base_conversion_rate = total_conversion / len(list_of_paths)

# %%
# defining a function to identify potential state transitions and output a dictionary containing these.
# this dictionary is then used as an input to calculate transition probabilities

def transition_states (list_of_paths):
    list_of_unique_channels = set(x for element in list_of_paths for x in element)
    transition_states = {x + '>' + y: 0 for x in list_of_unique_channels for y in list_of_unique_channels}
    
    for possible_state in list_of_unique_channels:
        if possible_state not in ['Conversion', 'Null']:
            for user_path in list_of_paths:
                if possible_state in user_path:
                    indices = [i for i, s in enumerate(user_path) if possible_state in s]
                    for col in indices:
                        transition_states[user_path[col] + '>' + user_path[col + 1]] +=1
                        
    return transition_states

trans_states = transition_states(list_of_paths)

# %%
# writing a function to calculate all transition probabilities
# the output will be a dictionary containing all transitions and their respective transition probabilities

def transition_prob(trans_dict):
    list_of_unique_channels = set(x for element in list_of_paths for x in element)
    trans_prob = defaultdict(dict)
    for state in list_of_unique_channels:
        if state not in ['Conversion', 'Null']:
            counter = 0
            index = [i for i, s in enumerate(trans_dict) if state + '>' in s]
            for col in index:
                if trans_dict[list(trans_dict)[col]] > 0:
                    counter += trans_dict[list(trans_dict)[col]]
            for col in index:
                if trans_dict[list(trans_dict)[col]] > 0:
                    state_prob = float((trans_dict[list(trans_dict)[col]])) / float(counter)
                    trans_prob[list(trans_dict)[col]] = state_prob
                    
    return trans_prob

trans_prob = transition_prob(trans_states)

# %%
# identifying removal effects for each marketing channel
# converting the dictionary into a df for matrix manipulation

def transition_matrix(list_of_paths, transition_prob):
    trans_matrix = pd.DataFrame()
    list_of_unique_channels = set(x for element in list_of_paths for x in element)
    
    for channel in list_of_unique_channels:
        trans_matrix[channel] = 0.00
        trans_matrix.loc[channel] = 0.00
        trans_matrix.loc[channel][channel] = 1.0 if channel in ['Conversion', 'Null'] else 0.0
        
    for key, value in trans_prob.items():
        origin, destination = key.split('>')
        trans_matrix.at[origin, destination] = value
        
    return trans_matrix

trans_matrix = transition_matrix(list_of_paths, trans_prob)
trans_matrix
# Out:
#                 Instagram  Conversion  Facebook  Start      Null  Paid Search  \
# Instagram        0.000000    0.057979  0.218777    0.0  0.629786     0.045809
# Conversion       0.000000    1.000000  0.000000    0.0  0.000000     0.000000
# Facebook         0.173072    0.053220  0.000000    0.0  0.673123     0.050655
# Start            0.119188    0.000000  0.278408    0.0  0.000000     0.317399
# Null             0.000000    0.000000  0.000000    0.0  1.000000     0.000000
# Paid Search      0.034196    0.053309  0.064442    0.0  0.770779     0.000000
# Online Display   0.029363    0.050324  0.053986    0.0  0.756643     0.092386
# Online Video     0.031908    0.078146  0.059323    0.0  0.763757     0.047947
#
#                 Online Display  Online Video
# Instagram             0.023531      0.024118
# Conversion            0.000000      0.000000
# Facebook              0.024352      0.025577
# Start                 0.142644      0.142361
# ...

# %%
plt.subplots(figsize=(20,15))
sns.set(font_scale= 1.4)
sns.heatmap(trans_matrix, annot= True, annot_kws={"size":16}, cmap="YlGnBu")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 1.5, top + 1.5)
# Out:
# (12.5, 4.5)

# %%
ax = sns.clustermap(trans_matrix)

# %%
# intitiating removal effect for each channel to assess the impact it would have on overall conversion
# adding resulting removal effects to an output dictionary

def removal_effects(df, conversion_rate):
    removal_effects_dict = {}
    channels = [channel for channel in df.columns if channel not in ['Start', 'Null', 'Conversion']]
    
    for channel in channels:
        removal_df = df.drop(channel, axis = 1).drop(channel, axis=0)
        for column in removal_df.columns:
            row_sum = np.sum(list(removal_df.loc[column]))
            null_pct = float(1) - row_sum
            if null_pct  != 0:
                removal_df.loc[column]['Null'] = null_pct
            removal_df.loc['Null']['Null'] = 1.0
            
        removal_to_conv = removal_df[['Null', 'Conversion']].drop(['Null', 'Conversion'], axis=0)
        removal_to_non_conv = removal_df.drop(['Null', 'Conversion'], axis=1).drop(['Null', 'Conversion'], axis=0)
        
        removal_inv_diff = np.linalg.inv(np.identity(len(removal_to_non_conv.columns)) - np.asarray(removal_to_non_conv))
        removal_dot_prod = np.dot(removal_inv_diff, np.asarray(removal_to_conv))
        removal_cvr = pd.DataFrame(removal_dot_prod, index = removal_to_conv.index)[[1]].loc['Start'].values[0]
        
        removal_effect = 1- removal_cvr / conversion_rate
        removal_effects_dict[channel] = removal_effect
        
    return removal_effects_dict

removal_effects_dict = removal_effects(trans_matrix, base_conversion_rate)

# %%
# using the resulting removal effects dictionary to calculate the Markov Chain attributions
# for each marketing channel

def markov_chain_allocations(removal_effects, total_conversions):
    re_sum = np.sum(list(removal_effects.values()))
    
    return{k: (v / re_sum) * total_conversions for k, v in removal_effects.items()}

attributions = markov_chain_allocations(removal_effects_dict, total_conversions)

# %%
# visualising the final conversions for each channel

df_paths = df_paths.append(attributions, ignore_index = True )
df_paths.head()
# Out:
#                       cookie                                      path  \
# 0  00000FkCnDfDDf0iC97iC703B  [Start, Instagram, Online Display, Null]
# 1  0000nACkD9nFkBBDECD3ki00E                [Start, Paid Search, Null]
# 2  0003EfE37E93D0BC03iBhBBhF                [Start, Paid Search, Null]
# 3  00073CFE3FoFCn70fBhB3kfon                  [Start, Instagram, Null]
# 4  00079hhBkDF3k3kDkiFi9EFAD                [Start, Paid Search, Null]
#
#    Facebook  Instagram  Online Display  Online Video  Paid Search
# 0       NaN        NaN             NaN           NaN          NaN
# 1       NaN        NaN             NaN           NaN          NaN
# 2       NaN        NaN             NaN           NaN          NaN
# 3       NaN        NaN             NaN           NaN          NaN
# 4       NaN        NaN             NaN           NaN          NaN

# %%
attributions
# Out:
# {'Instagram': 3031.5215485558915,
#  'Facebook': 4948.892177847523,
#  'Paid Search': 4618.891257291356,
#  'Online Display': 2153.2469267590823,
#  'Online Video': 2886.4480895461475}

# %%
channel = attributions.keys()
channel
# Out:
# dict_keys(['Instagram', 'Facebook', 'Paid Search', 'Online Display', 'Online Video'])

# %%
conversions = attributions.values()
conversions
# Out:
# dict_values([3031.5215485558915, 4948.892177847523, 4618.891257291356, 2153.2469267590823, 2886.4480895461475])

# %%
# plt.bar(*zip(*attributions.items()))
# plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title('attributions for each channel')
plt.ylabel('conversions')
plt.xlabel('channel')
sns.barplot(x = list(attributions.keys()), y = list(attributions.values()), palette= 'colorblind')
